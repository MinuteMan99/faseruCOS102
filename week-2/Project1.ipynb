# %% [markdown]
# BEGIN
#
# SET total = 0
#
# INPUT number_of_items
#
# FOR item = 1 TO number_of_items
#     INPUT item_price
#     total = total + item_price
# END FOR
#
# DISPLAY "Total amount =", total
#
# INPUT payment_amount
#
# IF payment_amount >= total THEN
#     change = payment_amount - total
#     DISPLAY "Payment successful"
#     DISPLAY "Change =", change
# ELSE
#     DISPLAY "Insufficient payment"
# END IF
#
# DISPLAY "Thank you for shopping"
#
# END
#
# ![Project1.png](attachment:dd19f7db-90f5-41c0-854a-3cf838d71d13.png)
